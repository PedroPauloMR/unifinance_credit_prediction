# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from feature_engine.discretisation import EqualFrequencyDiscretiser, EqualWidthDiscretiser
from feature_engine.imputation import MeanMedianImputer
from feature_engine.wrappers import SklearnTransformerWrapper
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.linear_model import LogisticRegression

import sys
import joblib
sys.path.insert(0,'../src/')
from utils.utils import load_config_file

from data.data_load import DataLoad
from data.data_validation import DataValidation
from data.data_transformation import DataTransformation
from data.data_preprocess import DataPreprocess
from train.train import TrainModels
from evaluation.classifier_eval import ModelEvaluation

pd.set_option('display.max_column',None)

# %% [markdown]
# # Data Load

# %%
dl = DataLoad()
df = dl.load_data('train_dataset_name')
# Out:
# 2024-01-18 07:33:24 [info     ] Initiating data load with name: train_dataset_name

# %% [markdown]
# # Data Validation

# %%
dv = DataValidation()
is_valid = dv.run(df)
# Out:
# 2024-01-18 07:33:24 [info     ] Initiating validation...
# 2024-01-18 07:33:25 [info     ] Validation columns passed...
# 2024-01-18 07:33:25 [info     ] Success on validate data

# %% [markdown]
# # Data Transformation

# %%
dt = DataTransformation(df)

# %%
X_train, X_val, y_train, y_val = dt.train_test_spliting()

# %% [markdown]
# # Experimentations

# %%
import mlflow
from mlflow.tracking import MlflowClient

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000')
mlflow.set_experiment('prob_loan')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1705570296224, experiment_id='1', last_update_time=1705570296224, lifecycle_stage='active', name='prob_loan', tags={}>

# %% [markdown]
# ## Select Best Model

# %%
current_experiment = dict(mlflow.get_experiment_by_name('prob_loan'))

# %%
experiment_id = current_experiment['experiment_id']

# %%
df_mlflow = mlflow.search_runs(filter_string='metrics.val_roc_auc < 1').sort_values('metrics.val_roc_auc',ascending = False)

# %%
df_mlflow
# Out:
#                              run_id experiment_id    status  \
# 1  126210dda4d445fdb7730040e4519711             1  FINISHED
# 2  2ebd13775aa044c280219d77905ee696             1  FINISHED
# 3  55b4f479ef954094b8afed894458002a             1  FINISHED
# 5  ace6b20f011f468ba68ddf6b8b202d85             1    FAILED
# 0  792661fa949a47618ef7362bee4ca11b             1  FINISHED
# 4  a3ec8c5e01dc489a9d14278706a480d2             1  FINISHED
# 6  473187f27f9b4b8bb363f0915cf2e1e4             1  FINISHED
#
#                                         artifact_uri  \
# 1  mlflow-artifacts:/1/126210dda4d445fdb7730040e4...
# 2  mlflow-artifacts:/1/2ebd13775aa044c280219d7790...
# 3  mlflow-artifacts:/1/55b4f479ef954094b8afed8944...
# 5  mlflow-artifacts:/1/ace6b20f011f468ba68ddf6b8b...
# 0  mlflow-artifacts:/1/792661fa949a47618ef7362bee...
# 4  mlflow-artifacts:/1/a3ec8c5e01dc489a9d14278706...
# 6  mlflow-artifacts:/1/473187f27f9b4b8bb363f0915c...
#
#                         start_time                         end_time  \
# 1 2024-01-18 10:27:12.499000+00:00 2024-01-18 10:27:22.164000+00:00
# 2 2024-01-18 10:27:02.160000+00:00 2024-01-18 10:27:12.306000+00:00
# 3 2024-01-18 10:26:51.900000+00:00 2024-01-18 10:27:02.106000+00:00
# 5 2024-01-18 10:00:36.330000+00:00 2024-01-18 10:03:03.689000+00:00
# 0 2024-01-18 10:27:22.221000+00:00 2024-01-18 10:27:33.883000+00:00
# 4 2024-01-18 10:26:41.597000+00:00 2024-01-18 10:26:51.849000+00:00
# 6 2024-01-18 09:44:57.813000+00:00 2024-01-18 09:45:03.919000+00:00
#
#    metrics.false_negatives  metrics.roc_auc  metrics.example_count  \
# 1                    321.0         0.840613                37500.0
# 2                    321.0         0.840595                37500.0
# 3                    530.0         0.831089                37500.0
# 5                   2398.0         0.800393                37500.0
# 0                   2398.0         0.800385                37500.0
# 4                   2398.0         0.800354                37500.0
# 6                      NaN              NaN                    NaN
#
#    metrics.val_roc_auc  metrics.precision_score  metrics.recall_score  \
# 1             0.840613                 0.135002              0.871907
# 2             0.840595                 0.134960              0.871907
# 3             0.831089                 0.169862              0.788508
# 5             0.800393                 0.600000              0.043097
# 0             0.800385                 0.600000              0.043097
# 4             0.800354                 0.600000              0.043097
# 6             0.709640                      NaN                   NaN
#
#    metrics.log_loss  metrics.true_negatives  metrics.true_positives  \
# 1          0.677543                 20994.0                  2185.0
# 2          0.677613                 20989.0                  2185.0
# 3          0.538590                 25337.0                  1976.0
# 5          0.203741                 34922.0                   108.0
# 0          0.203740                 34922.0                   108.0
# 4          0.203736                 34922.0                   108.0
# 6               NaN                     NaN                     NaN
#
#    metrics.precision_recall_auc  metrics.false_positives  \
# 1                      0.358467                  14000.0
# 2                      0.358438                  14005.0
# 3                      0.339271                   9657.0
# 5                      0.289661                     72.0
# 0                      0.289702                     72.0
# 4                      0.289784                     72.0
# 6                           NaN                      NaN
#
#    metrics.train_roc_auc  metrics.f1_score  metrics.accuracy_score  \
# 1               0.833471          0.233802                0.618107
# 2               0.833452          0.233740                0.617973
# 3               0.823008          0.279511                0.728347
# 5               0.792034          0.080417                0.934133
# 0               0.792015          0.080417                0.934133
# 4               0.791964          0.080417                0.934133
# 6               0.693620               NaN                     NaN
#
#    metrics.score params.warm_start  \
# 1       0.618107             False
# 2       0.617973              True
# 3       0.728347             False
# 5       0.934133              None
# 0       0.934133              True
# 4       0.934133              True
# 6            NaN              None
#
#                                        params.scaler            params.C  \
# 1  SklearnTransformerWrapper(transformer=Standard...  0.9518330371360946
# 2  SklearnTransformerWrapper(transformer=Standard...  0.5212475342689141
# 3  SklearnTransformerWrapper(transformer=Standard...   1.492768901018179
# 5  SklearnTransformerWrapper(transformer=Standard...                None
# 0  SklearnTransformerWrapper(transformer=Standard...  1.1691205548657253
# 4  SklearnTransformerWrapper(transformer=Standard...   2.244401289727354
# 6  SklearnTransformerWrapper(transformer=Standard...                None
#
#                                       params.imputer  \
# 1  MeanMedianImputer(variables=['RendaMensal', 'N...
# 2  MeanMedianImputer(variables=['RendaMensal', 'N...
# 3  MeanMedianImputer(variables=['RendaMensal', 'N...
# 5  MeanMedianImputer(variables=['RendaMensal', 'N...
# 0  MeanMedianImputer(variables=['RendaMensal', 'N...
# 4  MeanMedianImputer(variables=['RendaMensal', 'N...
# 6  MeanMedianImputer(variables=['RendaMensal', 'N...
#
#                                   params.discretizer params.solver  \
# 1  EqualFrequencyDiscretiser(variables=['TaxaDeUt...         lbfgs
# 2  EqualFrequencyDiscretiser(variables=['TaxaDeUt...     newton-cg
# 3  EqualFrequencyDiscretiser(variables=['TaxaDeUt...     liblinear
# 5  EqualFrequencyDiscretiser(variables=['TaxaDeUt...          None
# 0  EqualFrequencyDiscretiser(variables=['TaxaDeUt...     newton-cg
# 4  EqualFrequencyDiscretiser(variables=['TaxaDeUt...         lbfgs
# 6                                               None          None
#
#                params.tol params.class_weight params.fit_intercept  \
# 1  2.8021488428232038e-05            balanced                False
# 2   3.339600849088671e-05            balanced                False
# 3  5.0529297352594604e-05            balanced                 True
# 5                    None                None                 None
# 0   6.063510703680488e-05                None                 True
# 4   2.146759033312009e-05                None                 True
# 6                    None                None                 None
#
#   params.multi_class params.max_iter tags.mlflow.user tags.mlflow.source.type  \
# 1               auto             803            Pedro                   LOCAL
# 2               auto             327            Pedro                   LOCAL
# 3               auto             125            Pedro                   LOCAL
# 5               None            None            Pedro                   LOCAL
# 0               auto             236            Pedro                   LOCAL
# 4               auto             760            Pedro                   LOCAL
# 6               None            None            Pedro                   LOCAL
#
#                              tags.mlflow.source.name tags.model_name  \
# 1  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...     lr_hyperopt
# 2  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...     lr_hyperopt
# 3  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...     lr_hyperopt
# 5  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...  lr_discretizer
# 0  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...     lr_hyperopt
# 4  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...     lr_hyperopt
# 6  c:\Users\Pedro\.conda\envs\mlflow\lib\site-pac...     lr_baseline
#
#                                 tags.mlflow.datasets  \
# 1  [{"name":"cfc78614469742a54251023c73a82207","h...
# 2  [{"name":"cfc78614469742a54251023c73a82207","h...
# 3  [{"name":"cfc78614469742a54251023c73a82207","h...
# 5  [{"name":"cfc78614469742a54251023c73a82207","h...
# 0  [{"name":"cfc78614469742a54251023c73a82207","h...
# 4  [{"name":"cfc78614469742a54251023c73a82207","h...
# 6                                               None
#
#                        tags.mlflow.log-model.history  \
# 1  [{"run_id": "126210dda4d445fdb7730040e4519711"...
# 2  [{"run_id": "2ebd13775aa044c280219d77905ee696"...
# 3  [{"run_id": "55b4f479ef954094b8afed894458002a"...
# 5  [{"run_id": "ace6b20f011f468ba68ddf6b8b202d85"...
# 0  [{"run_id": "792661fa949a47618ef7362bee4ca11b"...
# 4  [{"run_id": "a3ec8c5e01dc489a9d14278706a480d2"...
# 6  [{"run_id": "473187f27f9b4b8bb363f0915cf2e1e4"...
#
#          tags.mlflow.runName
# 1  with_discretizer_hyperopt
# 2  with_discretizer_hyperopt
# 3  with_discretizer_hyperopt
# 5           with_discretizer
# 0  with_discretizer_hyperopt
# 4  with_discretizer_hyperopt
# 6                   baseline

# %%
run_id = df_mlflow.loc[df_mlflow['metrics.val_roc_auc'].idxmax()]['run_id']
run_id
# Out:
# '126210dda4d445fdb7730040e4519711'
